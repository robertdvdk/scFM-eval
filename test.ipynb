# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
drug_fm = {"MAE": (1.76, 0.26), "Per-drug PCC": (0.65, 0.018), "Global PCC": (0.58, 0.13)}
gcn = {"MAE": (1.89, 0.31), "Per-drug PCC": (0.64, 0.023), "Global PCC": (0.52, 0.15)}

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

models = ["Drug FM", "GCN"]
x = np.arange(len(models))
width = 0.6

# MAE plot (lower is better)
axes[0].bar(x, [drug_fm["MAE"][0], gcn["MAE"][0]], width, yerr=[drug_fm["MAE"][1], gcn["MAE"][1]], capsize=5, alpha=0.8)
axes[0].set_ylabel("MAE (lower is better)")
axes[0].set_title("Mean Absolute Error")
axes[0].set_xticks(x)
axes[0].set_xticklabels(models)
axes[0].grid(axis="y", alpha=0.3)

# Per-drug PCC plot (higher is better)
axes[1].bar(
    x,
    [drug_fm["Per-drug PCC"][0], gcn["Per-drug PCC"][0]],
    width,
    yerr=[drug_fm["Per-drug PCC"][1], gcn["Per-drug PCC"][1]],
    capsize=5,
    alpha=0.8,
)
axes[1].set_ylabel("PCC (higher is better)")
axes[1].set_title("Per-drug PCC")
axes[1].set_xticks(x)
axes[1].set_xticklabels(models)
axes[1].grid(axis="y", alpha=0.3)

# Global PCC plot (higher is better)
axes[2].bar(
    x,
    [drug_fm["Global PCC"][0], gcn["Global PCC"][0]],
    width,
    yerr=[drug_fm["Global PCC"][1], gcn["Global PCC"][1]],
    capsize=5,
    alpha=0.8,
)
axes[2].set_ylabel("PCC (higher is better)")
axes[2].set_title("Global PCC")
axes[2].set_xticks(x)
axes[2].set_xticklabels(models)
axes[2].grid(axis="y", alpha=0.3)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
drug_fm = {"MAE": (1.76, 0.26), "Per-drug PCC": (0.65, 0.018), "Global PCC": (0.58, 0.13)}
gcn = {"MAE": (1.89, 0.31), "Per-drug PCC": (0.64, 0.023), "Global PCC": (0.52, 0.15)}

# Define consistent colors for each model
drug_fm_color = "C0"  # blue
gcn_color = "C1"  # orange

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

models = ["Drug FM", "GCN"]
colors = [drug_fm_color, gcn_color]
x = np.arange(len(models))
width = 0.6

# MAE plot (lower is better)
axes[0].bar(
    x,
    [drug_fm["MAE"][0], gcn["MAE"][0]],
    width,
    yerr=[drug_fm["MAE"][1], gcn["MAE"][1]],
    capsize=5,
    alpha=0.8,
    color=colors,
)
axes[0].set_ylabel("MAE (lower is better)")
axes[0].set_title("Mean Absolute Error")
axes[0].set_xticks(x)
axes[0].set_xticklabels(models)
axes[0].grid(axis="y", alpha=0.3)

# Per-drug PCC plot (higher is better)
axes[1].bar(
    x,
    [drug_fm["Per-drug PCC"][0], gcn["Per-drug PCC"][0]],
    width,
    yerr=[drug_fm["Per-drug PCC"][1], gcn["Per-drug PCC"][1]],
    capsize=5,
    alpha=0.8,
    color=colors,
)
axes[1].set_ylabel("PCC (higher is better)")
axes[1].set_title("Per-drug PCC")
axes[1].set_xticks(x)
axes[1].set_xticklabels(models)
axes[1].grid(axis="y", alpha=0.3)

# Global PCC plot (higher is better)
axes[2].bar(
    x,
    [drug_fm["Global PCC"][0], gcn["Global PCC"][0]],
    width,
    yerr=[drug_fm["Global PCC"][1], gcn["Global PCC"][1]],
    capsize=5,
    alpha=0.8,
    color=colors,
)
axes[2].set_ylabel("PCC (higher is better)")
axes[2].set_title("Global PCC")
axes[2].set_xticks(x)
axes[2].set_xticklabels(models)
axes[2].grid(axis="y", alpha=0.3)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
drug_fm = {"MAE": (1.76, 0.26), "Per-drug PCC": (0.65, 0.018), "Global PCC": (0.58, 0.13)}
gcn = {"MAE": (1.89, 0.31), "Per-drug PCC": (0.64, 0.023), "Global PCC": (0.52, 0.15)}

# Define consistent colors for each model
drug_fm_color = "C0"  # blue
gcn_color = "C1"  # orange

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

models = ["Drug FM", "GCN"]
colors = [drug_fm_color, gcn_color]
x = np.arange(len(models))
width = 0.6

# MAE plot (lower is better)
axes[0].bar(
    x,
    [drug_fm["MAE"][0], gcn["MAE"][0]],
    width,
    yerr=[drug_fm["MAE"][1], gcn["MAE"][1]],
    capsize=5,
    alpha=0.8,
    color=colors,
)
axes[0].set_ylabel("MAE (lower is better)")
axes[0].set_title("Mean Absolute Error")
axes[0].set_xticks(x)
axes[0].set_xticklabels(models)
axes[0].grid(axis="y", alpha=0.3)

# Per-drug PCC plot (higher is better)
axes[1].bar(
    x,
    [drug_fm["Per-drug PCC"][0], gcn["Per-drug PCC"][0]],
    width,
    yerr=[drug_fm["Per-drug PCC"][1], gcn["Per-drug PCC"][1]],
    capsize=5,
    alpha=0.8,
    color=colors,
)
axes[1].set_ylabel("PCC (higher is better)")
axes[1].set_title("Per-drug PCC")
axes[1].set_xticks(x)
axes[1].set_xticklabels(models)
axes[1].set_ylim(0, 1)
axes[1].grid(axis="y", alpha=0.3)

# Global PCC plot (higher is better)
axes[2].bar(
    x,
    [drug_fm["Global PCC"][0], gcn["Global PCC"][0]],
    width,
    yerr=[drug_fm["Global PCC"][1], gcn["Global PCC"][1]],
    capsize=5,
    alpha=0.8,
    color=colors,
)
axes[2].set_ylabel("PCC (higher is better)")
axes[2].set_title("Global PCC")
axes[2].set_xticks(x)
axes[2].set_xticklabels(models)
axes[2].set_ylim(0, 1)
axes[2].grid(axis="y", alpha=0.3)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
drug_fm = {"MAE": (1.76, 0.26), "Per-drug PCC": (0.65, 0.018), "Global PCC": (0.58, 0.13)}
scgpt = {"MAE": (1.76, 0.27), "Per-drug PCC": (0.65, 0.02), "Global PCC": (0.57, 0.15)}
scgpt_cancer = {"MAE": (1.72, 0.27), "Per-drug PCC": (0.65, 0.02), "Global PCC": (0.59, 0.14)}

# Define consistent colors for each model
drug_fm_color = "C0"  # blue
scgpt_color = "C1"  # orange
scgpt_cancer_color = "C2"  # green

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

models = ["Drug FM", "scGPT", "scGPT (cancer)"]
colors = [drug_fm_color, scgpt_color, scgpt_cancer_color]
x = np.arange(len(models))
width = 0.6

# MAE plot (lower is better)
axes[0].bar(
    x,
    [drug_fm["MAE"][0], scgpt["MAE"][0], scgpt_cancer["MAE"][0]],
    width,
    yerr=[drug_fm["MAE"][1], scgpt["MAE"][1], scgpt_cancer["MAE"][1]],
    capsize=5,
    alpha=0.8,
    color=colors,
)
axes[0].set_ylabel("MAE (lower is better)")
axes[0].set_title("Mean Absolute Error")
axes[0].set_xticks(x)
axes[0].set_xticklabels(models)
axes[0].grid(axis="y", alpha=0.3)

# Per-drug PCC plot (higher is better)
axes[1].bar(
    x,
    [drug_fm["Per-drug PCC"][0], scgpt["Per-drug PCC"][0], scgpt_cancer["Per-drug PCC"][0]],
    width,
    yerr=[drug_fm["Per-drug PCC"][1], scgpt["Per-drug PCC"][1], scgpt_cancer["Per-drug PCC"][1]],
    capsize=5,
    alpha=0.8,
    color=colors,
)
axes[1].set_ylabel("PCC (higher is better)")
axes[1].set_title("Per-drug PCC")
axes[1].set_xticks(x)
axes[1].set_xticklabels(models)
axes[1].set_ylim(0, 1)
axes[1].grid(axis="y", alpha=0.3)

# Global PCC plot (higher is better)
axes[2].bar(
    x,
    [drug_fm["Global PCC"][0], scgpt["Global PCC"][0], scgpt_cancer["Global PCC"][0]],
    width,
    yerr=[drug_fm["Global PCC"][1], scgpt["Global PCC"][1], scgpt_cancer["Global PCC"][1]],
    capsize=5,
    alpha=0.8,
    color=colors,
)
axes[2].set_ylabel("PCC (higher is better)")
axes[2].set_title("Global PCC")
axes[2].set_xticks(x)
axes[2].set_xticklabels(models)
axes[2].set_ylim(0, 1)
axes[2].grid(axis="y", alpha=0.3)

plt.tight_layout()
plt.show()
