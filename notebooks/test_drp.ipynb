# %%
import pandas as pd

# %%
dose_response_matrix = pd.read_csv("./gdsc/processed_data/dose_response_matrix.csv", index_col=0)
dose_response_matrix
# Out:
#           1240121    1240122   1240123   1240125    1240127   1240128  \
# DRUG_ID
# 1003    -3.591777  -2.254537 -2.549696 -2.309753   1.657261 -3.767453
# 1004    -6.081340  -1.398731 -4.040787       NaN  -0.715093 -4.185140
# 1005     2.719967   3.895870  3.870937       NaN   5.028780  1.529066
# 1006     0.668355   3.081146  3.188992       NaN   4.262772  0.035444
# 1007    -6.605884  -4.611304 -3.005426 -4.008235  -3.888927 -3.995545
# ...           ...        ...       ...       ...        ...       ...
# 2177     1.776877   2.919563  0.765666  2.275460   3.031041  2.333547
# 2359     5.284673   6.343561  5.084562       NaN   5.980304  5.774320
# 2439     8.380496  10.153985  8.518213       NaN   9.290721  8.624764
# 2498     7.690044   8.664143  6.446104       NaN   8.699271  8.267526
# 2499     9.458618   9.851226  9.296432       NaN  10.974226  9.337866
#
#           1240129   1240130    1240131    1240132  ...    949175    949176  \
# ...

# %%
drug_embeddings = pd.read_csv("./gdsc/processed_data/drug_embeddings.csv", index_col=0)
drug_embeddings
# Out:
#             dim_0     dim_1     dim_2     dim_3     dim_4     dim_5     dim_6  \
# Drug_ID
# 1003     0.205559  0.333701  0.105239  0.772783 -0.482777 -0.040204 -0.481459
# 1004     0.558442 -0.020460  0.860087  0.152694  0.000029 -0.340525 -0.440267
# 1005     0.911908  0.345949 -0.770620  0.177454 -1.162906  0.365873  0.457736
# 1006     0.229714  0.245833  0.043467  0.902389 -1.112405 -0.140390 -0.254255
# 1007     0.421563  0.418567  0.436956  0.641985 -0.438951 -0.492306 -0.537505
# ...           ...       ...       ...       ...       ...       ...       ...
# 2177    -0.066507  0.453802  0.394314  0.569837 -0.196771 -0.457777  0.076666
# 2359    -0.058225  0.614080  0.287229  0.329475 -0.388324 -0.101988 -0.004882
# 2439    -0.098756  1.225959  0.659278  0.330038  0.140201 -0.088944 -0.219940
# 2498     0.871235  0.196512  0.525396  0.654860 -0.683847 -0.202433  0.097110
# 2499    -0.025703  0.960668  0.819441  0.618741  0.253581 -0.002409  0.098698
#
# ...

# %%
expr = pd.read_csv("./gdsc/processed_data/expr.csv", index_col=0)
expr
# Out:
#                 683667    684052     684057    684059     684062    684072  \
# GENE_SYMBOLS
# TSPAN6        7.780713  7.301344   8.233101  8.333466   8.391341  7.876188
# TNMD          2.753253  2.890533   2.824687  3.966757   2.968360  2.848546
# DPM1          9.960137  9.922489  10.015884  9.793991  10.260680  9.285925
# SCYL3         4.351073  4.125088   4.749715  3.976923   4.295875  4.456519
# C1orf112      3.716740  3.678987   3.839433  3.505669   4.129471  4.022855
# ...                ...       ...        ...       ...        ...       ...
# PPY2          3.230713  3.003521   3.031862  2.993918   2.959515  3.192067
# KRT18P55      3.102091  3.068187   3.322455  3.219777   3.056066  3.147401
# POLRMTP1      3.169188  3.135479   2.813440  3.033869   3.127004  3.085148
# UBL5P2        9.810430  9.073222   8.893197  8.691401   9.396462  9.211427
# TBC1D3P5      3.266915  3.098364   3.266184  3.279230   3.217885  3.323394
#
# ...

# %% [markdown]
# # Embed

# %%
import json

from cancerfoundation.model.model import CancerFoundation

# %%
vocab = json.load(open("./model_save/vocab.json", "r"))

# %%
model = CancerFoundation.load_from_checkpoint(
    "./model_save/epoch_epoch=14.ckpt",
    vocab=vocab,
    perturbation=True,
    strict=False,
    their_init_weights=False,
    compile_model=False,
    dropout=0.2,
    weights_only=False,
)
# Out:
# Support for conditions is not yet implemented, but this model has been pretrained with conditions. Performance may suffer!
# ...

# %%
model.eval()
# Out:
# CancerFoundation(
#   (criterion): MSE()
#   (model): PerturbationTransformer(
#     (value_encoder): TheirContinuousValueEncoder(
#       (dropout): Dropout(p=0.2, inplace=False)
#       (linear1): Linear(in_features=1, out_features=256, bias=True)
#       (activation): ReLU()
#       (linear2): Linear(in_features=256, out_features=256, bias=True)
#       (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (criterion_conditions): CrossEntropyLoss()
#     (criterion): MSE()
#     (condition_encoders): ModuleDict(
#       (technology): ConditionEncoder(
#         (embedding): Embedding(15, 256)
#         (enc_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (transformer_encoder): CFGenerator(
#       (layers): ModuleList(
#         (0-5): 6 x CFLayer(
#           (self_attn): MHA(
#             (self_attn): MultiheadAttention(
# ...

# %%
expr
# Out:
#                 683667    684052     684057    684059     684062    684072  \
# GENE_SYMBOLS
# TSPAN6        7.780713  7.301344   8.233101  8.333466   8.391341  7.876188
# TNMD          2.753253  2.890533   2.824687  3.966757   2.968360  2.848546
# DPM1          9.960137  9.922489  10.015884  9.793991  10.260680  9.285925
# SCYL3         4.351073  4.125088   4.749715  3.976923   4.295875  4.456519
# C1orf112      3.716740  3.678987   3.839433  3.505669   4.129471  4.022855
# ...                ...       ...        ...       ...        ...       ...
# PPY2          3.230713  3.003521   3.031862  2.993918   2.959515  3.192067
# KRT18P55      3.102091  3.068187   3.322455  3.219777   3.056066  3.147401
# POLRMTP1      3.169188  3.135479   2.813440  3.033869   3.127004  3.085148
# UBL5P2        9.810430  9.073222   8.893197  8.691401   9.396462  9.211427
# TBC1D3P5      3.266915  3.098364   3.266184  3.279230   3.217885  3.323394
#
# ...

# %%
expr.index
# Out:
# Index(['TSPAN6', 'TNMD', 'DPM1', 'SCYL3', 'C1orf112', 'FGR', 'CFH', 'FUCA2',
#        'GCLC', 'NFYA',
#        ...
#        'LINC00514', 'OR1D5', 'ZNF234', 'MYH4', 'LINC00526', 'PPY2', 'KRT18P55',
#        'POLRMTP1', 'UBL5P2', 'TBC1D3P5'],
#       dtype='object', name='GENE_SYMBOLS', length=17419)

# %%
vocab
# Out:
# {'<cls>': 0,
#  '<pad>': 1,
#  '<eoc>': 2,
#  'IGFBP7': 3,
#  'MED6': 4,
#  'LOC100289092': 5,
#  'RP11-554J4.1': 6,
#  'CAPNS2': 7,
#  'C2orf92': 8,
#  'CBS': 9,
#  'ERO1B': 10,
#  'LYST': 11,
#  'XKR4': 12,
#  'MARCO': 13,
#  'UCA1': 14,
#  'AC020910.4': 15,
#  'CBX2': 16,
#  'C20orf201': 17,
#  'PRR36': 18,
#  'IGHV3-33': 19,
#  'TRGV3': 20,
#  'NUDT7': 21,
#  'MIR3128': 22,
#  'ADH4': 23,
#  'KCTD19': 24,
#  'RP11-127B20.3': 25,
#  'AFF4': 26,
#  'GTPBP3': 27,
#  'LINC00887': 28,
#  'DIRAS3': 29,
#  'TRIM26': 30,
#  'CH25H': 31,
#  'MIR4269': 32,
#  'INSYN1-AS1': 33,
#  'TTN-AS1': 34,
#  'BCKDHA': 35,
#  'RP11-145M9.4': 36,
#  'ARHGEF10L': 37,
#  'SNORD116-12': 38,
#  'CLTC': 39,
#  'LEMD1-AS1': 40,
#  'MIR205HG': 41,
#  'HOXC-AS5': 42,
#  'BBS2': 43,
#  'GPHA2': 44,
#  'LINC01722': 45,
#  'GLI2': 46,
#  'HYDIN': 47,
#  'LRIT1': 48,
#  'SLC35A4': 49,
#  'RP5-1198O20.4': 50,
#  'NMI': 51,
#  'ATP5L2': 52,
#  'AL354811.1': 53,
#  'BMS1P18': 54,
#  'AC002310.6': 55,
# ...

# %%
len(set(expr.index).intersection(set(vocab.keys())))
# Out:
# 15842
